# %%
import pandas as pd
import numpy as np
import re

# %%
# setting to display all the columns and rows in the data# 
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# load the data into a dataframe
df = pd.read_csv('gurgaon_properties_cleaned.csv')

# %%
# check for duplicate rows
df.duplicated().sum()
# Out:
# 122

# %%
df.head(1)
# Out:
#   property_type      society     sector  price  price_per_sqft    area  \
# 0          flat  m3m heights  sector 65    2.5         13600.0  1838.0
#
#                              areaWithType  bedrooms  bathrooms balconies  \
# 0  Super Built up area 1828(169.83 sq.m.)         3          3         3
#
#   additional_room  floor_num facing       age_possession  \
# 0   not available       19.0    NaN  2024-12-01 00:00:00
#
#                                                                                                                                                                                                                                                                                       nearby_locations  \
# 0  ['Rapid Metro Sector 56', 'M3m 65th Avenue Mall', 'Golf Course Extension Road', 'Gurgaon - Delhi Expy', 'DPS International School', 'DPG Institute of Technology', 'Park Hospital', 'Indira Gandhi International Airport', 'Lemon Tree Hotel', 'SkyJumper Trampoline Park', 'PVR Drive in Theatre']
#
#   furnish_details features
# 0              []      NaN

# %% [markdown]
# ### 1. Area with type

# %%
df[['area', 'areaWithType']].sample(5)
# Out:
#         area  \
# 1743  2040.0
# 466   1736.0
# 1074  1165.0
# 3447   240.0
# 2192  1997.0
#
#                                                                                                                areaWithType
# 1743                                                                                     Built Up area: 2040 (189.52 sq.m.)
# 466                                                                                          Carpet area: 180 (150.5 sq.m.)
# 1074                                          Super Built up area 1950(181.16 sq.m.)Carpet area: 1161 sq.ft. (107.86 sq.m.)
# 3447                                                                                        Built Up area: 240 (22.3 sq.m.)
# 2192  Super Built up area 1997(185.53 sq.m.)Built Up area: 1790 sq.ft. (166.3 sq.m.)Carpet area: 1420 sq.ft. (131.92 sq.m.)

# %% [markdown]
# #### carpet area -> usable area of a property; excludes the thickness of the walls, for example
# #### built-up area -> usable area but also includes the wall thickness and area of other structural elements
# #### super built-up area -> total area of a property including balconies, verandah, etc.

# %%
def get_super_built_up_area(text):
    """
    a function that takes a description of the areaWithType as input
    and returns the value of Super Built up area if found
    """
    match = re.search(r'Super Built up area (\d+\.?\d*)', text)
    if match:
        return float(match.group(1))
    
    return None

def get_area(text, area_type):
    """
    a function that takes a description of the areaWithType and area type
    as input and returns the value of area type if found
    """
    match = re.search(area_type + r'\s*:\s*(\d+\.?\d*)', text)
    if match:
        return float(match.group(1))
    
    return None

def convert_to_sqft(text, area_value):
    """
    a function that converts
    """
    if area_value is None:
        return None
    
    match = re.search(r'{} \((\d+\.?\d*) sq.m.\)'.format(area_value), text)
    if match:
        sq_m_value = float(match.group(1))
        return sq_m_value * 10.7639 # conversion factor (sq.m to sq.ft)
    
    return area_value

# %%
# extract super built up area and convert to sqft
df['super_built_up_area'] = df['areaWithType'].apply(get_super_built_up_area)
df['super_built_up_area'] = df.apply(lambda x: convert_to_sqft(x['areaWithType'], x['super_built_up_area']), axis=1)

# extract built up area and convert to sqft
df['built_up_area'] = df['areaWithType'].apply(lambda x: get_area(x, 'Built Up area'))
df['built_up_area'] = df.apply(lambda x: convert_to_sqft(x['areaWithType'], x['built_up_area']), axis=1)

# extract super carpet area and convert to sqft
df['carpet_area'] = df['areaWithType'].apply(lambda x: get_area(x, 'Carpet area'))
df['carpet_area'] = df.apply(lambda x: convert_to_sqft(x['areaWithType'], x['carpet_area']), axis=1)

# %%
df[['property_type', 'price', 'area', 'areaWithType', 'super_built_up_area', 'built_up_area', 'carpet_area']].sample(5)
# Out:
#      property_type  price    area                            areaWithType  \
# 1065          flat   1.65  1877.0  Super Built up area 1877(174.38 sq.m.)
# 1118         house   3.99  4500.0            Plot area 4500(418.06 sq.m.)
# 1616          flat   1.35  1359.0  Super Built up area 1359(126.26 sq.m.)
# 3310          flat   0.54   830.0          Carpet area: 830 (77.11 sq.m.)
# 97            flat   1.50  2125.0  Super Built up area 2125(197.42 sq.m.)
#
#       super_built_up_area  built_up_area  carpet_area
# 1065               1877.0            NaN          NaN
# 1118                  NaN            NaN          NaN
# 1616               1359.0            NaN          NaN
# 3310                  NaN            NaN        830.0
# 97                 2125.0            NaN          NaN

# %%
df[~((df['super_built_up_area'].isnull()) | (df['built_up_area'].isnull()) | (df['carpet_area'].isnull()))][['property_type', 'price', 'area', 'areaWithType', 'super_built_up_area', 'built_up_area', 'carpet_area']].sample(5)
# Out:
#      property_type  price    area  \
# 3507          flat   1.50  1765.0
# 2207          flat   1.60  1910.0
# 3486          flat   1.83  2405.0
# 353           flat   2.00  1128.0
# 2614          flat   4.55  4550.0
#
#                                                                                                                   areaWithType  \
# 3507     Super Built up area 1750(162.58 sq.m.)Built Up area: 1480 sq.ft. (137.5 sq.m.)Carpet area: 1450 sq.ft. (134.71 sq.m.)
# 2207    Super Built up area 1910(177.44 sq.m.)Built Up area: 1700 sq.ft. (157.94 sq.m.)Carpet area: 1600 sq.ft. (148.64 sq.m.)
# 3486    Super Built up area 2408(223.71 sq.m.)Built Up area: 1925 sq.ft. (178.84 sq.m.)Carpet area: 1875 sq.ft. (174.19 sq.m.)
# 353   Super Built up area 1852(172.06 sq.m.)Built Up area: 1456 sq.ft. (135.27 sq.m.)Carpet area: 1128.09 sq.ft. (104.8 sq.m.)
# 2614       Super Built up area 4650(432 sq.m.)Built Up area: 4630 sq.ft. (430.14 sq.m.)Carpet area: 4550 sq.ft. (422.71 sq.m.)
#
#       super_built_up_area  built_up_area  carpet_area
# 3507               1750.0         1480.0      1450.00
# 2207               1910.0         1700.0      1600.00
# 3486               2408.0         1925.0      1875.00
# 353                1852.0         1456.0      1128.09
# 2614               4650.0         4630.0      4550.00

# %%
df[df['areaWithType'].str.contains('Plot')][['property_type', 'price', 'area', 'areaWithType', 'super_built_up_area', 'built_up_area', 'carpet_area']].sample(5)
# Out:
#      property_type  price    area  \
# 1175         house   8.50  4518.0
# 3333         house   1.30  1152.0
# 1940         house  10.75  3600.0
# 3172         house  16.00  4500.0
# 2967         house   3.25  1449.0
#
#                                                                                                        areaWithType  \
# 1175  Plot area 502(419.74 sq.m.)Built Up area: 500 sq.yards (418.06 sq.m.)Carpet area: 400 sq.yards (334.45 sq.m.)
# 3333                                                                                   Plot area 1152(107.02 sq.m.)
# 1940                                                                                    Plot area 400(334.45 sq.m.)
# 3172                                                                                    Plot area 500(418.06 sq.m.)
# 2967                                                                                    Plot area 161(134.62 sq.m.)
#
#       super_built_up_area  built_up_area  carpet_area
# 1175                  NaN          500.0        400.0
# 3333                  NaN            NaN          NaN
# 1940                  NaN            NaN          NaN
# 3172                  NaN            NaN          NaN
# 2967                  NaN            NaN          NaN

# %%
all_nan_df  = df[((df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & (df['carpet_area'].isnull()))][['property_type', 'price', 'area', 'areaWithType', 'super_built_up_area', 'built_up_area', 'carpet_area']]
all_nan_df.sample(5)
# Out:
#      property_type  price    area                 areaWithType  \
# 3264         house   3.75   160.0   Plot area 160(14.86 sq.m.)
# 2063         house  19.00  4518.0  Plot area 502(419.74 sq.m.)
# 1496         house  18.00  4518.0  Plot area 502(419.74 sq.m.)
# 210          house  12.00  3240.0  Plot area 360(301.01 sq.m.)
# 1236         house   0.85   900.0   Plot area 900(83.61 sq.m.)
#
#       super_built_up_area  built_up_area  carpet_area
# 3264                  NaN            NaN          NaN
# 2063                  NaN            NaN          NaN
# 1496                  NaN            NaN          NaN
# 210                   NaN            NaN          NaN
# 1236                  NaN            NaN          NaN

# %%
all_nan_df.shape
# Out:
# (546, 7)

# %%
all_nan_index = all_nan_df.index
all_nan_index
# Out:
# Int64Index([   9,   15,   29,   56,   57,   63,   69,   72,   81,  106,
#             ...
#             3751, 3754, 3756, 3762, 3771, 3779, 3785, 3787, 3788, 3796],
#            dtype='int64', length=546)

# %%
def extract_plot_area(area_with_type):
    """
    a function to extract the Plot area
    from the all nan df
    """
    match = re.search(r'Plot area (\d+\.?\d*)', area_with_type)
    if match:
        return float(match.group(1))
    return None

# %%
all_nan_df['built_up_area'] = all_nan_df['areaWithType'].apply(extract_plot_area)
all_nan_df.sample(5)
# Out:
#      property_type  price    area                 areaWithType  \
# 958          house   4.50  1350.0  Plot area 150(125.42 sq.m.)
# 2549         house   6.25  1800.0  Plot area 200(167.23 sq.m.)
# 2749         house   6.00  2700.0  Plot area 300(250.84 sq.m.)
# 2161         house   0.96   960.0   Plot area 945(87.79 sq.m.)
# 231          house   6.25  2034.0  Plot area 226(188.96 sq.m.)
#
#       super_built_up_area  built_up_area  carpet_area
# 958                   NaN          150.0          NaN
# 2549                  NaN          200.0          NaN
# 2749                  NaN          300.0          NaN
# 2161                  NaN          945.0          NaN
# 231                   NaN          226.0          NaN

# %% [markdown]
# ### Unit conversions:
# #### 1 sq ft = 9 x (1 sq yard)
# #### 1 sq ft = 10.7 x (1 sq m)

# %%
def convert_scale(row):
    """
    a function that converts the values in 
    built up area column into sq ft
    """
    if np.isnan(row['area']) or np.isnan(row['built_up_area']):
        return row['built_up_area']
    else:
        if round(row['area']/row['built_up_area']) == 9:      # area is in sq yards
            return row['built_up_area'] * 9
        elif round(row['area']/row['built_up_area']) == 11:   # area is in sq meters
            return row['built_up_area'] * 10.7
        else:                                                 # area is in sq ft
            return row['built_up_area']

# %%
# all_nan_df['built_up_area'] = all_nan_df.apply(convert_scale, axis=1)
all_nan_df.sample(5)
# Out:
#      property_type  price    area                 areaWithType  \
# 1248         house   6.00  2700.0  Plot area 300(250.84 sq.m.)
# 886          house   2.25   900.0   Plot area 100(83.61 sq.m.)
# 2227         house   3.30  1665.0  Plot area 185(154.68 sq.m.)
# 576          house   8.50  3240.0  Plot area 360(301.01 sq.m.)
# 3193         house   2.50  1557.0  Plot area 173(144.65 sq.m.)
#
#       super_built_up_area  built_up_area  carpet_area
# 1248                  NaN          300.0          NaN
# 886                   NaN          100.0          NaN
# 2227                  NaN          185.0          NaN
# 576                   NaN          360.0          NaN
# 3193                  NaN          173.0          NaN

# %%
# update the original dataframe
df.update(all_nan_df)

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                 487
# sector                    0
# price                    18
# price_per_sqft           18
# area                     18
# areaWithType              0
# bedrooms                  0
# bathrooms                 0
# balconies                 0
# additional_room           0
# floor_num                19
# facing                 1105
# age_possession            1
# nearby_locations        177
# furnish_details         981
# features                635
# super_built_up_area    1888
# built_up_area          2070
# carpet_area            1859
# dtype: int64

# %% [markdown]
# ### 2. Additional Rooms

# %%
df['additional_room'].value_counts()
# Out:
# not available                                    1587
# servant room                                      705
# study room                                        250
# others                                            225
# pooja room                                        165
# study room,servant room                            99
# store room                                         99
# pooja room,servant room                            82
# pooja room,study room,servant room,store room      72
# servant room,others                                60
# pooja room,study room,servant room                 55
# pooja room,study room,servant room,others          54
# servant room,pooja room                            38
# servant room,store room                            33
# study room,others                                  29
# pooja room,study room                              22
# pooja room,others                                  17
# pooja room,store room                              15
# pooja room,store room,study room,servant room      12
# servant room,study room                            12
# study room,servant room,store room                 11
# pooja room,servant room,others                     11
# study room,pooja room                              10
# servant room,study room,pooja room,store room      10
# study room,servant room,pooja room,store room       8
# store room,servant room                             8
# study room,servant room,others                      7
# pooja room,servant room,store room                  7
# pooja room,study room,store room                    7
# study room,pooja room,servant room                  7
# servant room,pooja room,store room                  6
# others,servant room                                 6
# pooja room,servant room,study room,store room       5
# store room,pooja room                               5
# study room,servant room,store room,pooja room       5
# study room,servant room,pooja room                  4
# servant room,store room,pooja room                  4
# pooja room,study room,others                        4
# study room,pooja room,store room                    4
# servant room,pooja room,study room,store room       3
# study room,pooja room,servant room,store room       3
# servant room,study room,pooja room                  3
# pooja room,study room,store room,servant room       3
# servant room,others,pooja room                      3
# store room,pooja room,study room,servant room       2
# study room,pooja room,store room,servant room       2
# store room,pooja room,servant room                  2
# store room,pooja room,study room                    2
# servant room,study room,store room                  2
# servant room,others,store room,pooja room           2
# study room,store room                               2
# study room,others,servant room                      1
# servant room,pooja room,store room,study room       1
# servant room,study room,store room,pooja room       1
# study room,store room,pooja room                    1
# store room,study room                               1
# others,study room                                   1
# store room,servant room,pooja room                  1
# servant room,pooja room,study room                  1
# store room,pooja room,servant room,study room       1
# servant room,store room,study room,pooja room       1
# store room,servant room,study room,pooja room       1
# servant room,study room,others                      1
# store room,study room,servant room                  1
# pooja room,store room,servant room                  1
# Name: additional_room, dtype: int64

# %%
# create a list of different type of additional room names
new_cols = ['study room', 'servant room', 'store room', 'pooja room', 'others']

# populate the new columns based on the information in the additional rooms column
for col in new_cols:
    df[col] = df['additional_room'].str.contains(col).astype(int)

# %%
df[['additional_room', 'study room', 'servant room', 'store room', 'pooja room', 'others']].sample(5)
# Out:
#             additional_room  study room  servant room  store room  pooja room  \
# 3356  pooja room,study room           1             0           0           1
# 2911      pooja room,others           0             0           0           1
# 129            servant room           0             1           0           0
# 3302          not available           0             0           0           0
# 2875          not available           0             0           0           0
#
#       others
# 3356       0
# 2911       1
# 129        0
# 3302       0
# 2875       0

# %% [markdown]
# ### 3. Age possession

# %%
df['age_possession'].value_counts()
# Out:
# 1 to 5 Year Old        1676
# 5 to 10 Year Old        575
# 0 to 1 Year Old         530
# undefined               332
# 10+ Year Old            310
# Under Construction       90
# Within 6 months          70
# Within 3 months          26
# 2023-12-01 00:00:00      22
# By 2023                  19
# By 2024                  17
# 2024-12-01 00:00:00      16
# 2024-03-01 00:00:00      14
# 2024-01-01 00:00:00       8
# 2024-10-01 00:00:00       8
# 2024-06-01 00:00:00       7
# 2025-12-01 00:00:00       7
# 2023-08-01 00:00:00       7
# 2023-11-01 00:00:00       5
# By 2025                   4
# 2024-08-01 00:00:00       4
# 2023-10-01 00:00:00       4
# 2023-09-01 00:00:00       4
# 2024-07-01 00:00:00       4
# 2025-01-01 00:00:00       3
# 2024-02-01 00:00:00       3
# 2024-11-01 00:00:00       3
# 2024-05-01 00:00:00       3
# 2026-12-01 00:00:00       2
# 2026-04-01 00:00:00       2
# 2025-10-01 00:00:00       2
# 2027-07-01 00:00:00       2
# By 2027                   2
# 2025-07-01 00:00:00       2
# 2025-09-01 00:00:00       2
# 2025-08-01 00:00:00       2
# 2027-06-01 00:00:00       2
# 2026-01-01 00:00:00       2
# 2025-03-01 00:00:00       2
# 2028-01-01 00:00:00       1
# 2027-01-01 00:00:00       1
# 2026-03-01 00:00:00       1
# 2025-06-01 00:00:00       1
# 2026-08-01 00:00:00       1
# 2026-07-01 00:00:00       1
# 2027-09-01 00:00:00       1
# 2025-11-01 00:00:00       1
# 2024-04-01 00:00:00       1
# Name: age_possession, dtype: int64

# %%
def categorize_age_possession(value):
    if pd.isna(value):
        return 'Undefined'
    if '0 to 1 Year Old' in value or 'Within 6 months' in value or 'Withing 3 months' in value:
        return 'New Property'
    if "1 to 5 Year Old" in value:
        return "Relatively New"
    if "5 to 10 Year Old" in value:
        return "Moderately Old"
    if "10+ Year Old" in value:
        return "Old Property"
    if "Under Construction" in value or "By" in value:
        return "Under Construction"
    try:
        # for entries like October 2023
        int(value.split(" ")[-1])
        return "Under Construction"
    except:
        return "Undefined"

# %%
df['age_possession'] = df['age_possession'].apply(categorize_age_possession)
df[['age_possession']].sample(5)
# Out:
#      age_possession
# 3340      Undefined
# 815       Undefined
# 2328      Undefined
# 2226      Undefined
# 2369      Undefined

# %%
df['age_possession'].value_counts()
# Out:
# 1 to 5 Year Old        1676
# 5 to 10 Year Old        575
# 0 to 1 Year Old         530
# undefined               332
# 10+ Year Old            310
# Under Construction       90
# Within 6 months          70
# Within 3 months          26
# 2023-12-01 00:00:00      22
# By 2023                  19
# By 2024                  17
# 2024-12-01 00:00:00      16
# 2024-03-01 00:00:00      14
# 2024-01-01 00:00:00       8
# 2024-10-01 00:00:00       8
# 2024-06-01 00:00:00       7
# 2025-12-01 00:00:00       7
# 2023-08-01 00:00:00       7
# 2023-11-01 00:00:00       5
# By 2025                   4
# 2024-08-01 00:00:00       4
# 2023-10-01 00:00:00       4
# 2023-09-01 00:00:00       4
# 2024-07-01 00:00:00       4
# 2025-01-01 00:00:00       3
# 2024-02-01 00:00:00       3
# 2024-11-01 00:00:00       3
# 2024-05-01 00:00:00       3
# 2026-12-01 00:00:00       2
# 2026-04-01 00:00:00       2
# 2025-10-01 00:00:00       2
# 2027-07-01 00:00:00       2
# By 2027                   2
# 2025-07-01 00:00:00       2
# 2025-09-01 00:00:00       2
# 2025-08-01 00:00:00       2
# 2027-06-01 00:00:00       2
# 2026-01-01 00:00:00       2
# 2025-03-01 00:00:00       2
# 2028-01-01 00:00:00       1
# 2027-01-01 00:00:00       1
# 2026-03-01 00:00:00       1
# 2025-06-01 00:00:00       1
# 2026-08-01 00:00:00       1
# 2026-07-01 00:00:00       1
# 2027-09-01 00:00:00       1
# 2025-11-01 00:00:00       1
# 2024-04-01 00:00:00       1
# Name: age_possession, dtype: int64

# %%
df['age_possession'] = df['age_possession'].apply(categorize_age_possession)
df['age_possession'].value_counts()
# Out:
# Relatively New        1676
# New Property           600
# Moderately Old         575
# Undefined              510
# Old Property           310
# Under Construction     132
# Name: age_possession, dtype: int64

# %% [markdown]
# ### 4. Furnish Details

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedrooms', 'bathrooms', 'balconies', 'additional_room',
#        'floor_num', 'facing', 'age_possession', 'nearby_locations',
#        'furnish_details', 'features', 'super_built_up_area', 'built_up_area',
#        'carpet_area', 'study room', 'servant room', 'store room', 'pooja room',
#        'others', 'y'],
#       dtype='object')

# %%
df[['furnish_details', 'features']].sample(5)
# Out:
#                                                                                                                                                                                                                                                           furnish_details  \
# 1289                                                                                                                                                                                                                                                                  NaN
# 812   ['1 Modular Kitchen', '4 AC', 'No Bed', 'No Chimney', 'No Curtains', 'No Dining Table', 'No Exhaust Fan', 'No Fan', 'No Geyser', 'No Light', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Wardrobe', 'No Washing Machine', 'No Water Purifier']
# 1938    ['3 Fan', '1 Exhaust Fan', '1 Dining Table', '3 Light', 'No AC', 'No Bed', 'No Chimney', 'No Curtains', 'No Geyser', 'No Modular Kitchen', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Wardrobe', 'No Washing Machine', 'No Water Purifier']
# 487       ['1 Wardrobe', '3 Fan', '1 Exhaust Fan', '2 Geyser', '5 Light', '1 Modular Kitchen', 'No AC', 'No Bed', 'No Chimney', 'No Curtains', 'No Dining Table', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Washing Machine', 'No Water Purifier']
# 3161                                                                                                                                                                                                                                                                  NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        features
# 1289                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ['Lift(s)', 'Maintenance Staff', 'Park', 'Piped-gas', 'Security Personnel', 'Shopping Centre', 'Waste Disposal', 'Rain Water Harvesting']
# 812                                                                                                                                                                                                                                                                                                                                                        ['Security / Fire Alarm', 'Power Back-up', 'Feng Shui / Vaastu Compliant', 'Intercom Facility', 'Lift(s)', 'Maintenance Staff', 'Water Storage', 'Piped-gas', 'Visitor Parking', 'Swimming Pool', 'Park', 'Security Personnel', 'Shopping Centre', 'Fitness Centre / GYM', 'Rain Water Harvesting', 'Club house / Community Center']
# 1938  ['Centrally Air Conditioned', 'Water purifier', 'Security / Fire Alarm', 'Feng Shui / Vaastu Compliant', 'Private Garden / Terrace', 'Intercom Facility', 'Lift(s)', 'High Ceiling Height', 'Maintenance Staff', 'Water Storage', 'Separate entry for servant room', 'No open drainage around', 'Bank Attached Property', 'Piped-gas', 'Internet/wi-fi connectivity', 'Recently Renovated', 'Visitor Parking', 'Swimming Pool', 'Park', 'Security Personnel', 'Natural Light', 'Airy Rooms', 'Spacious Interiors', 'Low Density Society', 'Waste Disposal', 'Rain Water Harvesting', 'Water softening plant', 'Shopping Centre', 'Fitness Centre / GYM', 'Club house / Community Center']
# 487                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ['Feng Shui / Vaastu Compliant', 'Lift(s)', 'Maintenance Staff', 'Swimming Pool', 'Park', 'Visitor Parking', 'Shopping Centre', 'Fitness Centre / GYM', 'Club house / Community Center']
# 3161                                                                                                                                                                                                                                                                                                                                                                                                                                                                ['Power Back-up', 'Security / Fire Alarm', 'Intercom Facility', 'Lift(s)', 'Swimming Pool', 'Maintenance Staff', 'Water Storage', 'Park', 'Fitness Centre / GYM', 'Club house / Community Center', 'Rain Water Harvesting']

# %%
all_furnishings = []

for detail in df['furnish_details'].dropna():
    furnishings = detail.replace('[', '').replace(']', '').replace("'", "").split(', ')
    all_furnishings.extend(furnishings)
unique_furnishings = list(set(all_furnishings))

# %%
def get_furnishing_count(details, furnishing):
    """
    a function that evaluates a string of furnish details
    and returns the count of the specific furnishing mentioned
    """
    if isinstance(details, str):
        
        # no {furninshing}
        if f"No {furnishing}" in details:
            return 0
        
        # k {furnishing} where k > 0
        pattern = re.compile(f'(\d+) {furnishing}')
        match = pattern.search(details)
        
        if match:
            return int(match.group(1))
        
        # {furnishing}
        elif furnishing in details:
            return 1
    
    # if none of the above conditions are met
    return 0

# %%
# remove the "No" prefix and digits from all the elemnts in unique_furnishing
columns_furnishing = [re.sub(r'No |\d+', '', furnishing).strip() for furnishing in unique_furnishings]   
columns_furnishing = list(set(columns_furnishing))                                            # remove redundant elements
columns_furnishing = [furnishing for furnishing in columns_furnishing if furnishing]         # remove empty strings

# %%
# create new columns for each unique furnishing category and populate with the respective counts
for furnishing in columns_furnishing:
    df[furnishing] = df['furnish_details'].apply(lambda x: get_furnishing_count(x, furnishing))
    
# convert the list into a separate dataframe
furnishing_df = df[['furnish_details'] + columns_furnishing]

# %%
furnishing_df.shape
# Out:
# (3803, 19)

# %%
furnishing_df.drop(columns='furnish_details', inplace=True)
furnishing_df.sample(5)
# Out:
# /tmp/ipykernel_26019/3265581078.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   furnishing_df.drop(columns='furnish_details', inplace=True)
#       AC  Chimney  Dining Table  Washing Machine  Bed  Curtains  \
# 3188   5        1             0                1    0         0
# 1022   2        1             1                0    2         0
# 489    3        0             0                0    0         0
# 1091   4        1             1                0    0         1
# 28     0        0             0                0    0         0
#
#       Water Purifier  TV  Light  Stove  Geyser  Microwave  Wardrobe  Fridge  \
# 3188               0   0     10      1       3          1         3       1
# 1022               0   0     15      0       3          0         7       0
# 489                0   0      0      0       0          0         0       0
# 1091               0   1      8      0       2          0         1       0
# 28                 0   0      0      0       0          0         0       0
#
#       Exhaust Fan  Modular Kitchen  Sofa  Fan
# 3188            1                1     0    5
# 1022            1                1     0   12
# 489             0                0     0    0
# 1091            1                1     0    4
# 28              1                1     0    3

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(furnishing_df)

# %%
wcss_reduced = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(scaled_data)
    wcss_reduced.append(kmeans.inertia_)
# Out:
# /home/shwetank/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/shwetank/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/shwetank/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/shwetank/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/shwetank/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/shwetank/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/shwetank/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/shwetank/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/shwetank/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/shwetank/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
plt.figure(figsize=(12, 8))
plt.plot(range(1, 11), wcss_reduced,marker='o', linestyle='--')
plt.title('Elbow Method For Optimal Number of Clusters (Reduced Range)')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.grid(True)
plt.show()

# %%
n_clusters = 3

# create and train another model with the specified no. of clusters 
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
kmeans.fit(scaled_data)

# predict the cluster numbers for each row in the data
cluster_assignments = kmeans.predict(scaled_data)
# Out:
# /home/shwetank/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
df.head(1)
# Out:
#   property_type      society     sector  price  price_per_sqft    area  \
# 0          flat  m3m heights  sector 65    2.5         13600.0  1838.0
#
#                              areaWithType  bedrooms  bathrooms balconies  \
# 0  Super Built up area 1828(169.83 sq.m.)         3          3         3
#
#   additional_room  floor_num facing age_possession  \
# 0   not available       19.0    NaN      Undefined
#
#                                                                                                                                                                                                                                                                                       nearby_locations  \
# 0  ['Rapid Metro Sector 56', 'M3m 65th Avenue Mall', 'Golf Course Extension Road', 'Gurgaon - Delhi Expy', 'DPS International School', 'DPG Institute of Technology', 'Park Hospital', 'Indira Gandhi International Airport', 'Lemon Tree Hotel', 'SkyJumper Trampoline Park', 'PVR Drive in Theatre']
#
#   furnish_details features  super_built_up_area  built_up_area  carpet_area  \
# 0              []      NaN               1828.0            NaN          NaN
#
#    study room  servant room  store room  pooja room  others  AC  Chimney  \
# 0           0             0           0           0       0   0        0
#
#    Dining Table  Washing Machine  Bed  Curtains  Water Purifier  TV  Light  \
# 0             0                0    0         0               0   0      0
#
#    Stove  Geyser  Microwave  Wardrobe  Fridge  Exhaust Fan  Modular Kitchen  \
# 0      0       0          0         0       0            0                0
#
#    Sofa  Fan
# 0     0    0

# %%
df = df.iloc[:, :-18]
df['furnishing_type'] = cluster_assignments
df[['furnish_details', 'furnishing_type']].sample(5)
# Out:
#                                                                                                                                                                                                                                                           furnish_details  \
# 783          ['4 Wardrobe', '1 Water Purifier', '5 Fan', '1 Exhaust Fan', '4 Geyser', '1 Stove', '12 Light', '9 AC', '1 Chimney', '1 Modular Kitchen', 'No Bed', 'No Curtains', 'No Dining Table', 'No Microwave', 'No Fridge', 'No Sofa', 'No TV', 'No Washing Machine']
# 3241       ['3 Wardrobe', '5 Fan', '1 Exhaust Fan', '3 Geyser', '10 Light', '1 Curtains', '1 Modular Kitchen', '1 Chimney', 'No AC', 'No Bed', 'No Dining Table', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Washing Machine', 'No Water Purifier']
# 2953                                                                                                                                                                                                                                                                  NaN
# 461   ['1 Fan', '1 Light', 'No AC', 'No Bed', 'No Chimney', 'No Curtains', 'No Dining Table', 'No Exhaust Fan', 'No Geyser', 'No Modular Kitchen', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Wardrobe', 'No Washing Machine', 'No Water Purifier']
# 3383                                                                                                                                                                                                                                                                  NaN
#
#       furnishing_type
# 783                 1
# 3241                1
# 2953                0
# 461                 0
# 3383                0

# %%
df['furnishing_type'].value_counts()
# Out:
# 0    2501
# 1    1081
# 2     221
# Name: furnishing_type, dtype: int64

# %% [markdown]
# 0 = **unfurnished** <br>
# 1 = **semifurnished** <br>
# 2 = **furnished** <br>
