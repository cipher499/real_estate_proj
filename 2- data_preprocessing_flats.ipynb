# %% [markdown]
# ## Data Preprocessing- Gurgaon Flats Data
# ### @cipher499
# ### 06/12/23

# %%
import pandas as pd
import numpy as np
import re

# %%
# setting to display all the columns and rows in the data
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# read the data into a dataframe
df = pd.read_excel('data/gurgaon/flats/flats.xlsx')
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave      50 Lac
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend      70 Lac
#
#               area                            areaWithType    bedrooms  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#      bathrooms    balconies additional_room  \
# 0  2 Bathrooms    1 Balcony             NaN
# ...

# %%
# dimensions of the dataset
df.shape
# Out:
# (3018, 18)

# %%
# columns and their datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3018 entries, 0 to 3017
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   property_name     3018 non-null   object
#  1   society           3017 non-null   object
#  2   price             3008 non-null   object
#  3   area              3005 non-null   object
#  4   areaWithType      3009 non-null   object
#  5   bedrooms          3009 non-null   object
#  6   bathrooms         3009 non-null   object
#  7   balconies         3009 non-null   object
#  8   additional_room   1695 non-null   object
#  9   address           3003 non-null   object
#  10  floor_num         3007 non-null   object
#  11  facing            2128 non-null   object
#  12  age_possession    3008 non-null   object
#  13  nearby_locations  2914 non-null   object
#  14  description       3009 non-null   object
#  15  furnish_details   2204 non-null   object
# ...

# %%
# check for any duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
# check for any null values
df.isnull().sum()
# Out:
# property_name          0
# society                1
# price                 10
# area                  13
# areaWithType           9
# bedrooms               9
# bathrooms              9
# balconies              9
# additional_room     1323
# address               15
# floor_num             11
# facing               890
# age_possession        10
# nearby_locations     104
# description            9
# furnish_details      814
# features             423
# rating               341
# dtype: int64

# %%
# rename the area column
df.rename(columns={'area':'price_per_sqft'}, inplace=True)
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave      50 Lac
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend      70 Lac
#
#     price_per_sqft                            areaWithType    bedrooms  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#      bathrooms    balconies additional_room  \
# 0  2 Bathrooms    1 Balcony             NaN
# ...

# %%
# analyse the society column
# df.society.value_counts()
df.society.value_counts().shape
# Out:
# (639,)

# %%
# apply a regex transformation to parse out society names
df.society = df.society.apply(lambda name: re.sub(r'\d+(\.\d+)?\s?★', '', str(name)).strip()).str.lower()
df.society.value_counts().shape
# Out:
# (605,)

# %%
# df.price.value_counts()
df[(df.price == 'Price on Request') | (df.price == 'price')]
# Out:
#                          property_name                    society  \
# 25      5 BHK Flat in Sector 1 Gurgaon  the new people apartments
# 286                      property_name                    society
# 1645   4 BHK Flat in Sector 50 Gurgaon                ss hibiscus
# 1973   1 BHK Flat in Sector 31 Gurgaon            raheja atlantis
# 2055   2 BHK Flat in Sector 79 Gurgaon         supertech araville
# 2358  2 BHK Flat in Sector 37D Gurgaon            the millennia 2
# 2523  2 BHK Flat in Sector 95A Gurgaon              the roselia 2
# 2550      3 BHK Flat in Sector-2 Sohna         supertech hilltown
# 2641  2 BHK Flat in Sector 95A Gurgaon              the roselia 2
# 2960  3 BHK Flat in Sector 104 Gurgaon              godrej summit
# 2973         4 BHK Flat in Gwal Pahari     krrish provence estate
# 2974   4 BHK Flat in Sector 95 Gurgaon    sidhartha ncr one phase
#
#                  price price_per_sqft  \
# 25    Price on Request            NaN
# ...

# %%
# remove the rows in which price is not mentioned
df = df[(df.price != 'Price on Request') & (df.price != 'price')]
df.shape
# Out:
# (3006, 18)

# %%
df.society.value_counts().shape
# Out:
# (602,)

# %%
def treat_price(x):
    """
    this function converts the price into crores
    """
    if type(x) == float:
        return x
    else:
        if x[1] == 'Lac':
            return round(float(x[0])/100, 2)
        else:
            return round(float(x[0]), 2)

# %%
# apply the function to the price column
df.price = df.price.str.split(' ').apply(treat_price)
df.price.head(10)
# Out:
# 0    0.45
# 1    0.50
# 2    0.40
# 3    1.47
# 4    0.70
# 5    0.41
# 6    2.00
# 7    1.80
# 8    1.10
# 9    4.75
# Name: price, dtype: float64

# %%
# extract the float value of the price per sqft column
# df['price_per_sqft'].value_counts()
df['price_per_sqft'] = df['price_per_sqft'].str.split('/').str.get(0).str.replace('₹', '').str.replace(',','').str.strip().astype('float')

# %%
df.sample(5)
# Out:
#                            property_name                       society  price  \
# 1827    4 BHK Flat in Sector 106 Gurgaon                    paras dews   1.40
# 2924  1 BHK Flat in Golf Course Ext Road  ikon tower baani city centre    NaN
# 2621           4 BHK Flat in DLF Phase 5            dlf royalton tower   6.20
# 21       3 BHK Flat in Sector 79 Gurgaon                bestech altura   1.85
# 988      2 BHK Flat in Sector 85 Gurgaon                   ss the leaf   1.10
#
#       price_per_sqft                                       areaWithType  \
# 1827          9978.0  Super Built up area 2355(218.79 sq.m.)Built Up...
# 2924         12437.0                                                NaN
# 2621         20687.0             Super Built up area 2997(278.43 sq.m.)
# 21            8604.0             Super Built up area 2150(199.74 sq.m.)
# 988          12471.0  Super Built up area 1640(152.36 sq.m.)Built Up...
#
#         bedrooms    bathrooms     balconies additional_room  \
# ...

# %%
df['areaWithType'].value_counts().head(15)
# Out:
# Super Built up area 1578(146.6 sq.m.)                                            17
# Super Built up area 1350(125.42 sq.m.)                                           17
# Super Built up area 1950(181.16 sq.m.)Carpet area: 1161 sq.ft. (107.86 sq.m.)    17
# Super Built up area 1650(153.29 sq.m.)Carpet area: 1022.58 sq.ft. (95 sq.m.)     15
# Super Built up area 2010(186.74 sq.m.)                                           14
# Super Built up area 2150(199.74 sq.m.)                                           12
# Super Built up area 1950(181.16 sq.m.)                                           11
# Carpet area: 1650 (153.29 sq.m.)                                                 11
# Super Built up area 1920(178.37 sq.m.)                                           10
# Super Built up area 1550(144 sq.m.)                                              10
# Carpet area: 1150 (106.84 sq.m.)                                                 10
# ...

# %%
df.bedrooms.isnull().sum()
# Out:
# 9

# %%
df[df.bedrooms.isnull()]
# Out:
#                                   property_name                       society  \
# 2850           2 BHK Flat in Sector 107 Gurgaon       signature global solera
# 2851            4 BHK Flat in Sector 53 Gurgaon                tulip monsella
# 2852              2 BHK Flat in New Palam Vihar                       my home
# 2853                        2 BHK Flat in Sohna        breez global hill view
# 2923           3 BHK Flat in Sector 99A Gurgaon      pareena coban residences
# 2924         1 BHK Flat in Golf Course Ext Road  ikon tower baani city centre
# 2925            2 BHK Flat in Sector 89 Gurgaon                   greenopolis
# 2927  4 BHK Flat in C Block Sushant Lok Phase 1                 maple heights
# 2928            2 BHK Flat in Sector 99 Gurgaon                assotech blith
#
#       price  price_per_sqft areaWithType bedrooms bathrooms balconies  \
# 2850    NaN             NaN          NaN      NaN       NaN       NaN
# ...

# %%
# as the rows containing null values in bedroom have null in other columns too, drop them
df = df[~df.bedrooms.isnull()]

# %%
# extract the integer value from bedrooms
df.bedrooms = df.bedrooms.str.split(' ').str.get(0).astype('int')
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedrooms  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)         2
#
#      bathrooms    balconies additional_room  \
# 0  2 Bathrooms    1 Balcony             NaN
# 1  2 Bathrooms    1 Balcony             NaN
# ...

# %%
df.balconies.value_counts()
# Out:
# 3 Balconies     974
# 3+ Balconies    862
# 2 Balconies     749
# 1 Balcony       315
# No Balcony       97
# Name: balconies, dtype: int64

# %%
# extract the integer values from bathrooms and balconies columns
df.bathrooms = df.bathrooms.str.split(' ').str.get(0).astype('int')
df.balconies = df.balconies.str.split(' ').str.get(0).str.replace('No', '0')
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedrooms  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)         2
#
#    bathrooms balconies additional_room                              address  \
# 0          2         1             NaN     Krishna Colony, Gurgaon, Haryana
# ...

# %%
df.additional_room.value_counts()
# Out:
# Servant Room                                     629
# Study Room                                       232
# Others                                           179
# Pooja Room                                       132
# Study Room,Servant Room                           81
# Store Room                                        76
# Pooja Room,Servant Room                           60
# Servant Room,Others                               52
# Servant Room,Pooja Room                           30
# Study Room,Others                                 27
# Pooja Room,Study Room,Servant Room,Others         25
# Pooja Room,Study Room,Servant Room                24
# Servant Room,Store Room                           19
# Pooja Room,Study Room                             13
# Pooja Room,Study Room,Servant Room,Store Room     12
# Study Room,Pooja Room                              8
# Servant Room,Study Room                            8
# Study Room,Servant Room,Store Room                 7
# ...

# %%
df.additional_room.isnull().sum()
# Out:
# 1305

# %%
# fill the null values in the additional_room column
df.additional_room.fillna('not available', inplace=True)
df.additional_room = df.additional_room.str.lower()
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft                            areaWithType  bedrooms  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)         2
#
#    bathrooms balconies additional_room                              address  \
# 0          2         1   not available     Krishna Colony, Gurgaon, Haryana
# ...

# %%
# df.floor_num.value_counts()

# %%
df[df.floor_num.isnull()]
# Out:
#                                 property_name             society  price  \
# 181   3 BHK Flat in Dwarka Expressway Gurgaon  experion heartsong   1.08
# 2767          2 BHK Flat in Sector 78 Gurgaon                 nan   0.60
#
#       price_per_sqft                        areaWithType  bedrooms  bathrooms  \
# 181           6150.0  Built Up area: 1758 (163.32 sq.m.)         3          3
# 2767          3692.0  Built Up area: 1625 (150.97 sq.m.)         2          2
#
#      balconies additional_room  \
# 181          0   not available
# 2767         0   not available
#
#                                                 address floor_num facing  \
# 181   604, Tower B-3, 6th Floor,Sector 108, Dwarka E...       NaN    NaN
# 2767       Gurgaon, Sector 78 Gurgaon, Gurgaon, Haryana       NaN    NaN
#
#           age_possession nearby_locations  \
# 181   Under Construction              NaN
# 2767  Under Construction              NaN
#
# ...

# %%
# extract the number value from the floor_num column
df.floor_num = df.floor_num.str.split(' ').str.get(0).replace('Ground', '0').str.replace('Lower', '0').str.replace('Basement', '-1').str.extract(r'(\d+)')
df.sample(10)
# Out:
#                          property_name                    society  price  \
# 1726   3 BHK Flat in Sector 69 Gurgaon               tulip violet   1.55
# 2253     3 BHK Flat in Sector 36 Sohna    signature global park 4   0.85
# 992    3 BHK Flat in Sector 83 Gurgaon     vatika lifestyle homes   1.10
# 631   2 BHK Flat in Sector 108 Gurgaon     experion the heartsong   0.90
# 1922  2 BHK Flat in Sector 103 Gurgaon        satya the hermitage   0.89
# 2407   2 BHK Flat in Sector 79 Gurgaon                godrej aria   1.30
# 1708   3 BHK Flat in Sector 79 Gurgaon         mapsko mount ville   1.50
# 1247  4 BHK Flat in Sector 37C Gurgaon         imperia the esfera   1.40
# 2064   2 BHK Flat in Sector 92 Gurgaon         sare crescent parc   0.50
# 2478  2 BHK Flat in Sector 63A Gurgaon  signature global city 63a   1.65
#
#       price_per_sqft                                       areaWithType  \
# 1726          9639.0             Super Built up area 1608(149.39 sq.m.)
# ...

# %%
df.facing.value_counts()
# Out:
# North-East    505
# East          490
# North         301
# South         203
# West          183
# North-West    162
# South-East    144
# South-West    135
# Name: facing, dtype: int64

# %%
# check for null values in the facing column
df.facing.isnull().sum()
# Out:
# 874

# %%
# fill the null values with NA
df.facing.fillna('NA', inplace=True)

# %%
# create new columns: area and property type
df.insert(loc=4, column='area', value=round((df.price*10000000)/df.price_per_sqft))
df.insert(loc=1, column='property_type', value='flat')
df.head()
# Out:
#                      property_name property_type                 society  \
# 0     2 BHK Flat in Krishna Colony          flat  maa bhagwati residency
# 1        2 BHK Flat in Ashok Vihar          flat            apna enclave
# 2              2 BHK Flat in Sohna          flat  tulsiani easy in homes
# 3  2 BHK Flat in Sector 61 Gurgaon          flat     smart world orchard
# 4  2 BHK Flat in Sector 92 Gurgaon          flat        parkwood westend
#
#    price  price_per_sqft    area                            areaWithType  \
# 0   0.45          5000.0   900.0          Carpet area: 900 (83.61 sq.m.)
# 1   0.50          7692.0   650.0          Carpet area: 650 (60.39 sq.m.)
# 2   0.40          6722.0   595.0          Carpet area: 595 (55.28 sq.m.)
# 3   1.47         12250.0  1200.0        Carpet area: 1200 (111.48 sq.m.)
# 4   0.70          5204.0  1345.0  Super Built up area 1345(124.95 sq.m.)
#
#    bedrooms  bathrooms balconies additional_room  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2997 entries, 0 to 3017
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   property_name     2997 non-null   object
#  1   property_type     2997 non-null   object
#  2   society           2997 non-null   object
#  3   price             2996 non-null   float64
#  4   price_per_sqft    2996 non-null   float64
#  5   area              2996 non-null   float64
#  6   areaWithType      2997 non-null   object
#  7   bedrooms          2997 non-null   int64
#  8   bathrooms         2997 non-null   int64
#  9   balconies         2997 non-null   object
#  10  additional_room   2997 non-null   object
#  11  address           2991 non-null   object
#  12  floor_num         2995 non-null   object
#  13  facing            2997 non-null   object
#  14  age_possession    2996 non-null   object
#  15  nearby_locations  2906 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# property_name         0
# property_type         0
# society               0
# price                 1
# price_per_sqft        1
# area                  1
# areaWithType          0
# bedrooms              0
# bathrooms             0
# balconies             0
# additional_room       0
# address               6
# floor_num             2
# facing                0
# age_possession        1
# nearby_locations     91
# description           0
# furnish_details     797
# features            407
# rating              329
# dtype: int64

# %%
# export the cleaned dataset to a csv file
df.to_csv('flats_cleaned.csv', index=False)
